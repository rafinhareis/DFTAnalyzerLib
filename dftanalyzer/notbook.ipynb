# %%
import dftanalyzer as dft
# Out:
# Software de visualizacao de arquivos de DFT v1.0.0
# By Rafael Reis Barreto, contato rafinhareis17@gmail.com

# %%
names = {'files_folder':'D:/Doutorado/Artigos/Colab/Polesi/MoO3/dft/bulk'}
MoO3_bulk = dft.Load_bands_files(names = names,code = 'siesta',prefix='MoO3_bulk')

# %%
dft.Bands_plot(MoO3_bulk)
# Out:
# <Axes: title={'center': 'Band Structure'}, ylabel='$E -E_{F} (eV)$'>
